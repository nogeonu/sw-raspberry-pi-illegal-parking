# %%
import cv2
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from ultralytics import YOLO, checks
checks()
# Out:
# Ultralytics YOLOv8.2.58  Python-3.10.13 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3070, 8191MiB)
# Setup complete  (12 CPUs, 15.8 GB RAM, 375.3/438.7 GB disk)

# %%
### 영상 출력 함수
def fn_imshow(img, axis='on', **kwargs):
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(**kwargs)
    if axis!='on': plt.axis('off')
    plt.imshow(img_rgb)
    plt.show()

# %%
# Load a model
model = YOLO('yolov8n.yaml').load('yolov8n.pt') # build from YAML and transfer weights
# Out:
# Transferred 355/355 items from pretrained weights

# %%
# Train the model
model.train(data=r"C:/yolo_car/car.v3i.yolov8/data.yaml",
            epochs=100,
           pretrained='yolov8n.pt',
            batch=-1,
            imgsz=640,
            patience=100,
            project='Nano_car_pt')
# Out:
# New https://pypi.org/project/ultralytics/8.2.70 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.58  Python-3.10.13 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3070, 8191MiB)
# ...

# %% [markdown]
# # Test

# %%
import cv2
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import csv
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %%
# %matplotlib inline

# %%
# 영상 출력 함수
def fn_imshow(img, axis='on', figsize=(6, 8), **kwargs):
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=figsize)
    if axis != 'on':
        plt.axis('off')
    
    # 이미지 크기 가져오기
    height, width, _ = img.shape
    extent = [0, width, height, 0]  # extent 설정
    
    plt.imshow(img_rgb, extent=extent, **kwargs)
    plt.show()

# %%
# 예제 이미지 불러오기
img = cv2.imread(r"C:/Users/RTY2022/Downloads/car.jpg")

# 함수 호출
fn_imshow(img, axis='off', figsize=(6, 8))

# %%
#Load trained YOLOv8n model
pt_path = r"C:/yolo_car/New_car2_pt/train2/weights/best.pt"
model_best = YOLO(pt_path)

# %%
# Read an image using OpenCV
src =r"C:/Users/RTY2022/Downloads/car.jpg"
source = cv2.imread(src)
# Run inference on the source
results = model_best(source)
# Out:
# 0: 384x640 1 car_number, 119.0ms
# Speed: 2.5ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Plotting results
res_plotted = results[0].plot()
fn_imshow(res_plotted, axis='off', figsize=(6, 8))
